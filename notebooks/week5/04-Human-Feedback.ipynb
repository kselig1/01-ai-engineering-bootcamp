# %% [markdown]
# ### Import Dependencies

# %%
from langsmith import Client

# %% [markdown]
# ### Attach Feedback to a Specific Trace

# %% [markdown]
# 86ca47c2-cf57-4d64-bd36-337d32b550e1

# %%
client = Client()

# %%
client.create_feedback(
    run_id = "86ca47c2-cf57-4d64-bd36-337d32b550e1", 
    key = "feedback", 
    score = 0,  
    feedback_source_type = "api" 
)
# Out:
# Feedback(id=UUID('0def4973-2b74-47f1-9d5d-0f692597dcc8'), created_at=datetime.datetime(2025, 10, 31, 19, 53, 9, 933879, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2025, 10, 31, 19, 53, 9, 933881, tzinfo=datetime.timezone.utc), run_id=UUID('86ca47c2-cf57-4d64-bd36-337d32b550e1'), trace_id=None, key='feedback', score=0, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id = "86ca47c2-cf57-4d64-bd36-337d32b550e1", 
    key = "feedback_1", 
    score = 1,  
    feedback_source_type = "api" 
)
# Out:
# Feedback(id=UUID('e695d8f8-3028-49a3-be3a-c3c995f0c547'), created_at=datetime.datetime(2025, 10, 31, 19, 54, 36, 331163, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2025, 10, 31, 19, 54, 36, 331167, tzinfo=datetime.timezone.utc), run_id=UUID('86ca47c2-cf57-4d64-bd36-337d32b550e1'), trace_id=None, key='feedback_1', score=1, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id = "86ca47c2-cf57-4d64-bd36-337d32b550e1", 
    key = "comment", 
    value = "This is a long form feedback you should use to improve the system",  
    feedback_source_type = "api" 
)
# Out:
# Feedback(id=UUID('82ead9cb-9ede-4722-b126-c8d68b167e22'), created_at=datetime.datetime(2025, 10, 31, 19, 56, 21, 204837, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2025, 10, 31, 19, 56, 21, 204840, tzinfo=datetime.timezone.utc), run_id=UUID('86ca47c2-cf57-4d64-bd36-337d32b550e1'), trace_id=None, key='comment', score=None, value='This is a long form feedback you should use to improve the system', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
